# %%
import pandas as pd
import numpy as np

# %%
df_diamonds = pd.read_csv ('../db/Diamondssql.csv')
df_diamonds
# Out:
#                                                    Index Color        Cut  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...     J    Premium
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...     H  Very Good
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...     G       Fair
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...     D       Good
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...     G      Ideal
# ...                                                  ...   ...        ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...     G      Ideal
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...     F       Good
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...     H      Ideal
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...     J      Ideal
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...     I      Ideal
#
#       Clarity  Price       City  Depth  Table     X     Y     Z  Carat  \
# ...

# %%
cities=df_diamonds['City'].unique()
cities
# Out:
# array(['Dubai', 'Kimberly', 'Las Vegas', 'Tel Aviv', 'Amsterdam',
#        'Zurich', 'Antwerp', 'Madrid', 'Paris', 'Surat', 'Luxembourg',
#        'London', 'New York City'], dtype=object)

# %%
dict1={'Dubai':'Asia','Kimberly':'Africa','Las Vegas':'America', 'Tel Aviv':'Asia', 'Amsterdam':'Europe','Zurich':'Europe','Antwerp':'Europe', 'Madrid':'Europe','Paris':'Europe','Surat':'Asia', 'Luxembourg':'Europe','London':'Europe', 'New York City':'America'}
dict1
# Out:
# {'Dubai': 'Asia',
#  'Kimberly': 'Africa',
#  'Las Vegas': 'America',
#  'Tel Aviv': 'Asia',
#  'Amsterdam': 'Europe',
#  'Zurich': 'Europe',
#  'Antwerp': 'Europe',
#  'Madrid': 'Europe',
#  'Paris': 'Europe',
#  'Surat': 'Asia',
#  'Luxembourg': 'Europe',
#  'London': 'Europe',
#  'New York City': 'America'}

# %%
df_diamonds['Continent']=df_diamonds['City'].map(dict1)
df_diamonds
# Out:
#                                                    Index Color        Cut  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...     J    Premium
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...     H  Very Good
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...     G       Fair
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...     D       Good
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...     G      Ideal
# ...                                                  ...   ...        ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...     G      Ideal
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...     F       Good
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...     H      Ideal
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...     J      Ideal
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...     I      Ideal
#
#       Clarity  Price       City  Depth  Table     X     Y     Z  Carat  \
# ...

# %%
df_diamonds1 = df_diamonds[df_diamonds.duplicated(['Depth','Table','X','Y','Z'], keep=False)]
df_diamonds1
# Out:
#                                                    Index Color        Cut  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...     J    Premium
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...     H  Very Good
# 15     e629fa6598d732768f7c726b4b621285f9c3b85303900a...     G       Good
# 22     785f3ec7eb32f30b90cd0fcf3657d388b5ff4297f2f971...     G  Very Good
# 24     c2356069e9d1e79ca924378153cfbbfb4d4416b1f99d41...     G    Premium
# ...                                                  ...   ...        ...
# 40405  a04c23499b380163a45148db577e37e02c309c7b020137...     G    Premium
# 40417  65f6a89ba2e1d6d4ebb97333dab39daaddbadd393ab82d...     G       Good
# 40425  dff43fac32be7cf4e2b5b60e653ec93e0e7b58288c2374...     F      Ideal
# 40446  5609aeee890a691e5542100acdb83a3604a4d8bd51599e...     I      Ideal
# 40449  1726e8e229489b353e6007fac1dfffb5300a96bf6166cf...     F      Ideal
#
#       Clarity  Price      City  Depth  Table     X     Y     Z  Carat  \
# ...

# %%
df_diamonds2 = df_diamonds[df_diamonds.duplicated(['Depth','Table','X','Y','Z'])]
df_diamonds2
# Out:
#                                                    Index Color        Cut  \
# 469    c6bd343ae0007cdb979de7540f2668fe849d68ff47fa1a...     J      Ideal
# 475    b1585fdb272b31401eaac5dd46a936c1c09b4861e53e23...     I      Ideal
# 1013   2ec42bc1f3e672fc1cf7fdcfc23246415dcf20f03c0d4a...     G      Ideal
# 1685   c2f61742e5f0ef0a74c5fcbeff7ff659def91bf4b5f1e1...     G      Ideal
# 1951   3510a92fc7dd04f69b1aeeef5489ef168dbf1d9c4d528b...     F  Very Good
# ...                                                  ...   ...        ...
# 40405  a04c23499b380163a45148db577e37e02c309c7b020137...     G    Premium
# 40417  65f6a89ba2e1d6d4ebb97333dab39daaddbadd393ab82d...     G       Good
# 40425  dff43fac32be7cf4e2b5b60e653ec93e0e7b58288c2374...     F      Ideal
# 40446  5609aeee890a691e5542100acdb83a3604a4d8bd51599e...     I      Ideal
# 40449  1726e8e229489b353e6007fac1dfffb5300a96bf6166cf...     F      Ideal
#
#       Clarity  Price        City  Depth  Table     X     Y     Z  Carat  \
# ...

# %%
df_diamonds.to_csv('../db/Diamondssql.csv', index=False)
